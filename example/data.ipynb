# %%
import pandas as pd
import FreeBack as FB

# %%
#data = pd.read_feather('D://cloud/data/stock_data/DB_daily.feather').\
#    set_index(['date', 'code']).loc['2023':'2024']
#data[data['close']<3].to_csv('data.csv.xz', compression='xz')

# %%
data = pd.read_csv('data.csv.xz', parse_dates=['date']).\
    set_index(['date', 'code'])

# %%
data
# Out:
#                         name  open  high   low  close         vol  \
# date       code
# 2023-01-03 000005.SZ    ST星源  1.85  1.88  1.83   1.87   5836600.0
#            000008.SZ    神州高铁  2.31  2.39  2.30   2.36  18526330.0
#            000046.SZ   *ST泛海  1.25  1.26  1.24   1.26  34471100.0
#            000150.SZ   *ST宜康  1.40  1.40  1.37   1.40  20351119.0
#            000413.SZ    东旭光电  1.79  1.81  1.77   1.80  19034701.0
# ...                      ...   ...   ...   ...    ...         ...
# 2024-01-02 603077.SH    和邦生物  2.37  2.38  2.36   2.36  35094754.0
#            603555.SH    ST贵人  1.58  1.63  1.58   1.59  23955200.0
#            603557.SH    ST起步  2.20  2.31  2.19   2.30  16591137.0
#            603603.SH   *ST博天  1.44  1.44  1.44   1.44    396600.0
#            688538.SH  和辉光电-U  2.43  2.45  2.43   2.43  23816328.0
#
#                            amount  ex_factor  free_float_shares  float_shares  \
# date       code
# ...
