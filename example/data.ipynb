# %%
import pandas as pd
import FreeBack as FB

# %%
data = pd.read_feather('D://cloud/data/stock_data/DB_daily.feather').\
    set_index(['date', 'code']).loc['2021':'2024']
data[data['close']>100].to_csv('data.csv.xz', compression='xz')

# %%
data = pd.read_csv('data.csv.xz', parse_dates=['date']).\
    set_index(['date', 'code'])

# %%
data
# Out:
#                       name    open    high     low   close         vol  \
# date       code
# 2021-01-04 000538.SZ  云南白药  113.90  124.96  113.02  124.96  20044740.0
#            000568.SZ  泸州老窖  228.00  243.88  228.00  240.85  15433467.0
#            000596.SZ  古井贡酒  270.80  284.64  267.00  279.66   4159819.0
#            000661.SZ  长春高新  454.00  476.00  450.00  473.45   7103745.0
#            000799.SZ   酒鬼酒  156.51  172.15  155.80  172.15  12458526.0
# ...                    ...     ...     ...     ...     ...         ...
# 2024-01-02 688639.SH  华恒生物  125.81  125.81  118.52  121.19   1308087.0
#            688686.SH   奥普特  112.00  113.19  108.54  108.54    434976.0
#            688696.SH  极米科技  113.01  113.04  109.89  109.89    379779.0
#            688776.SH  国光电气  100.70  105.79   95.42  102.38   3780947.0
#            832982.BJ  锦波生物  262.79  267.66  260.12  264.97    145461.0
#
#                             amount  ex_factor  free_float_shares  \
# date       code
# 2021-01-04 000538.SZ  2.424452e+09  18.150787        462405068.0
#            000568.SZ  3.669629e+09  32.728099        717247024.0
#            000596.SZ  1.156936e+09   3.424490        112195978.0
#            000661.SZ  3.328959e+09   7.433691        275473781.0
#            000799.SZ  2.078455e+09   2.028288        224201689.0
# ...                            ...        ...                ...
# 2024-01-02 688639.SH  1.582468e+08   1.474711        101882294.0
#            688686.SH  4.791152e+07   1.501707         34323455.0
#            688696.SH  4.215345e+07   1.436183         41143196.0
#            688776.SH  3.842613e+08   1.405460         34474541.0
#            832982.BJ  3.844768e+07   2.487486         23758489.0
#
#                       float_shares  total_shares
# date       code
# 2021-01-04 000538.SZ  6.021670e+08  1.277403e+09
#            000568.SZ  1.464307e+09  1.464752e+09
#            000596.SZ  3.836000e+08  5.036000e+08
#            000661.SZ  3.551826e+08  4.047203e+08
#            000799.SZ  3.249290e+08  3.249290e+08
# ...                            ...           ...
# 2024-01-02 688639.SH  1.019403e+08  1.575402e+08
#            688686.SH  6.162946e+07  1.222355e+08
#            688696.SH  4.567055e+07  7.000000e+07
#            688776.SH  3.447454e+07  1.083834e+08
#            832982.BJ  2.375849e+07  6.808600e+07
#
# [110378 rows x 11 columns]
